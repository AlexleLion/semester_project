# %%
import os

def rename_files(dossier_pdf):
    # Liste des fichiers PDF dans le dossier
    pdf_files = [f for f in os.listdir(dossier_pdf) if f.endswith('.pdf')]

    # Renommer les fichiers en ajoutant un numéro en ordre croissant
    for i, filename in enumerate(sorted(pdf_files), start=1):
        new_filename = f"{i:02d}_{filename}"
        os.rename(os.path.join(dossier_pdf, filename), os.path.join(dossier_pdf, new_filename))

    # Afficher les nouveaux noms de fichiers
    print("Fichiers renommés :")
    for filename in sorted(os.listdir(dossier_pdf)):
        if filename.endswith('.pdf'):
            print(filename)
            
rename_files('../sources/ouvrages_mixtes')
rename_files('../sources/ouvrages_masculins')
rename_files('../sources/ouvrages_feminins')
# Out:
# Fichiers renommés :
# 01_Le_Livre_d'or_de_la_[...]Verbolenska_Loetitia_bpt6k1410941f.pdf
# 02_Le_livre_des_jeunes_mères_[...]Millet-Robinet_Cora_bpt6k935011n (1).pdf
# 03_Manuel_de_gymnastique_rationnelle_et_[...]Soleirol_de_bpt6k64781710.pdf

# %%
from pdf2image import convert_from_path
import os

# Chemin du dossier contenant les fichiers PDF
dossier_pdf = '../sources/ouvrages_feminins/20'

# Liste des fichiers PDF dans le dossier
pdf_files = [f for f in os.listdir(dossier_pdf) if f.endswith('.pdf')]
for pdf_file in pdf_files:
    # Transformer chaque PDF en fichiers JPG
    # Créer un dossier pour chaque PDF
    pdf_name = os.path.splitext(pdf_file)[0]

    output_folder = os.path.join(dossier_pdf, pdf_name[:9])
    if not os.path.exists(output_folder):
        os.makedirs(output_folder, exist_ok=True)

    # Chemin complet du fichier PDF
    pdf_path = os.path.join(dossier_pdf, pdf_file)
    print(pdf_path)
    
    # Convertir le PDF en images
    images = convert_from_path(pdf_path)

    # Sauvegarder chaque page en tant que fichier JPG
    for i, image in enumerate(images):
        image_path = os.path.join(output_folder, f'page_{i+1}.jpg')
        image.save(image_path, 'JPEG')

    print("Conversion terminée.")
# Out:
# ../sources/ouvrages_feminins/20/20_part4.pdf
# Conversion terminée.
# ../sources/ouvrages_feminins/20/20_part5.pdf
# Conversion terminée.
# ../sources/ouvrages_feminins/20/20_part2.pdf
# Conversion terminée.
# ../sources/ouvrages_feminins/20/20_part3.pdf
# Conversion terminée.

# %%
import pytesseract
from PIL import Image
import os
import pandas as pd
import random

# Chemin du dossier contenant les fichiers JPG
dossier_jpg = '../sources/ouvrages_feminins/20_part1'

#---------------------------------------------------A changer-------------------------------------------------------------------------    
# Liste des fichiers JPG dans le dossier
# Récupérer un fichier JPG aléatoire dans le dossier
jpg_file = [f for f in os.listdir(dossier_jpg) if f.endswith('.jpg')]
jpg_files = [jpg_file]
#----------------------------------------------------------------------------------------------------------------------------

# Extraire le texte de chaque image et stocker dans une liste
data = []
for jpg_file in jpg_files:
    image_path = os.path.join(dossier_jpg, jpg_file)
    print(image_path)
    text = pytesseract.image_to_string(Image.open(image_path))
    data.append({'filename': jpg_file, 'text': text})

# Convertir la liste en DataFrame
df = pd.DataFrame(data)

# Sauvegarder en CSV
if not os.path.exists('../data/csv/ouvrages_mixtes'):
    os.makedirs('../data/csv/ouvrages_mixtes', exist_ok=True)
csv_path =  '../data/csv/ouvrages_mixtes/' + os.path.splitext(jpg_file)[0] + '.csv'
df.to_csv(csv_path, index=False)

# Sauvegarder en JSON
if not os.path.exists('../data/json/ouvrages_mixtes'):
    os.makedirs('../data/json/ouvrages_mixtes', exist_ok=True)
json_path = '../data/json/ouvrages_mixtes/' + os.path.splitext(jpg_file)[0] + '.json'
df.to_json(json_path, orient='records', lines=True)

print("Transformation terminée. Les fichiers CSV et JSON ont été créés.")
# Out:
# ../sources/ouvrages_mixtes/01/1727623497750-2c4adfc9-af88-4a27-ac0c-046f2b74fad2]Verbolenska_Loetitia_bpt6k1410941f_30.jpg
# Transformation terminée. Les fichiers CSV et JSON ont été créés.

# %%
import pytesseract
from PIL import Image
import os
import pandas as pd
import random

# Chemin du dossier contenant les fichiers JPG
dossier_jpg = '../sources/ouvrages_mixtes/02'

if not os.path.exists(dossier_jpg):
    os.makedirs(dossier_jpg)
# Récupérer un fichier JPG aléatoire dans le dossier
jpg_files = [f for f in os.listdir(dossier_jpg) if f.endswith('.jpg')]

# Extraire le texte de chaque image et stocker dans une liste
data = []
for jpg_file in jpg_files:
    image_path = os.path.join(dossier_jpg, jpg_file)
    print(image_path)
    text = pytesseract.image_to_string(Image.open(image_path))
    data.append({'filename': jpg_file, 'text': text})

# Convertir la liste en DataFrame
df = pd.DataFrame(data)

# Sauvegarder en CSV
if not os.path.exists('../data/csv/ouvrages_mixtes'):
    os.makedirs('../data/csv/ouvrages_mixtes', exist_ok=True)
csv_path =  '../data/csv/ouvrages_mixtes/' + os.path.splitext(jpg_file)[0] + '.csv'
df.to_csv(csv_path, index=False)

# Sauvegarder en JSON
if not os.path.exists('../data/json/ouvrages_mixtes'):
    os.makedirs('../data/json/ouvrages_mixtes', exist_ok=True)
json_path = '../data/json/ouvrages_mixtes/' + os.path.splitext(jpg_file)[0] + '.json'
df.to_json(json_path, orient='records', lines=True)

print("Transformation terminée. Les fichiers CSV et JSON ont été créés.")
# Out:
# Transformation terminée. Les fichiers CSV et JSON ont été créés.

# %%
import pytesseract
from PIL import Image
import os
import pandas as pd
import random

# Chemin du dossier contenant les fichiers JPG
dossier_jpg = '../sources/ouvrages_mixtes/03'

#---------------------------------------------------A changer-------------------------------------------------------------------------    
# Liste des fichiers JPG dans le dossier
# Récupérer un fichier JPG aléatoire dans le dossier
jpg_file = random.choice([f for f in os.listdir(dossier_jpg) if f.endswith('.jpg')])
jpg_files = [jpg_file]
#----------------------------------------------------------------------------------------------------------------------------

# Extraire le texte de chaque image et stocker dans une liste
data = []
for jpg_file in jpg_files:
    image_path = os.path.join(dossier_jpg, jpg_file)
    print(image_path)
    text = pytesseract.image_to_string(Image.open(image_path))
    data.append({'filename': jpg_file, 'text': text})

# Convertir la liste en DataFrame
df = pd.DataFrame(data)

# Sauvegarder en CSV
if not os.path.exists('../data/csv/ouvrages_mixtes'):
    os.makedirs('../data/csv/ouvrages_mixtes', exist_ok=True)
csv_path =  '../data/csv/ouvrages_mixtes/' + os.path.splitext(jpg_file)[0] + '.csv'
df.to_csv(csv_path, index=False)

# Sauvegarder en JSON
if not os.path.exists('../data/json/ouvrages_mixtes'):
    os.makedirs('../data/json/ouvrages_mixtes', exist_ok=True)
json_path = '../data/json/ouvrages_mixtes/' + os.path.splitext(jpg_file)[0] + '.json'
df.to_json(json_path, orient='records', lines=True)

print("Transformation terminée. Les fichiers CSV et JSON ont été créés.")

# %%
import pytesseract
from PIL import Image, ImageOps
import os
import pandas as pd
import numpy as np
import cv2

dossier_jpg = '../sources/ouvrages_feminins/20_part1'

subfolders = [f.path for f in os.scandir(dossier_jpg) if f.is_dir()]

# Parcourir chaque sous-dossier
for subfolder in subfolders:
    jpg_files = [f for f in os.listdir(subfolder) if f.endswith('.jpg')]

    data = []
    for jpg_file in jpg_files:
        image_path = os.path.join(subfolder, jpg_file)
        
        image = cv2.imread(image_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        image = cv2.fastNlMeansDenoising(image, None, 8, 10, 21)

        final_image = Image.fromarray(image)
        
        text = pytesseract.image_to_string(image, config='--oem 3 --psm 6')
        data.append({'filename': jpg_file, 'text': text})
        
        df = pd.DataFrame(data)
        
        dossier_nom = os.path.basename(subfolder)
        dossier_suffix = dossier_nom[-2:]
        
        if text.strip():
            # Sauvegarder en TXT
            txt_dir = f'../data/txt/ouvrages_feminins/{dossier_suffix}'
            if not os.path.exists(txt_dir):
                os.makedirs(txt_dir, exist_ok=True)
            txt_path = os.path.join(txt_dir, os.path.splitext(jpg_file)[0] + '.txt')
            with open(txt_path, 'w', encoding='utf-8') as file:
                file.write(text)
        else:
            # Ajouter une entrée dans le DataFrame pour les pages vides
            empty_pages = pd.DataFrame([{'dossier': dossier_nom, 'page': jpg_file}])
            if 'empty_pages_df' in globals():
                empty_pages_df = pd.concat([empty_pages_df, empty_pages], ignore_index=True)
            else:
                empty_pages_df = empty_pages

# %%
import pytesseract
from PIL import Image, ImageOps
import os
import pandas as pd
import numpy as np
import cv2

dossier_jpg = '../sources/ouvrages_mixtes/01'

jpg_files = ["page_21.jpg"]

data = []
for jpg_file in jpg_files:
    image_path = os.path.join(subfolder, jpg_file)
    
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.fastNlMeansDenoising(image, None, 8, 10, 21)

    final_image = Image.fromarray(image)
    final_image.show()

# %%
import pytesseract
from PIL import Image, ImageOps
import os
import pandas as pd
import numpy as np
import cv2

dossier = '../sources/ouvrages_feminins/20'
dossier_jpgs = [f.path for f in os.scandir(dossier) if f.is_dir()]

# Liste des fichiers JPG dans le dossier
for dossier_jpg in dossier_jpgs:
    jpg_files = [f for f in os.listdir(dossier_jpg) if f.endswith('.jpg')]

    # Extraire le texte de chaque image et stocker dans une liste
    data = []
    for jpg_file in jpg_files:
        image_path = os.path.join(dossier_jpg, jpg_file)
        
        image = cv2.imread(image_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        image = cv2.fastNlMeansDenoising(image, None, 8, 10, 21)

        final_image = Image.fromarray(image)

        text = pytesseract.image_to_string(image, config='--oem 3 --psm 6')
        data.append({'filename': jpg_file, 'text': text})

        # Convertir la liste en DataFrame
        df = pd.DataFrame(data)

        # Sauvegarder en TXT
        dossier_nom = os.path.basename(dossier_jpg)
        
        txt_dir = f'../data/txt/ouvrages_feminins/{dossier_nom}'

        if not os.path.exists(txt_dir):
            os.makedirs(txt_dir, exist_ok=True)
            
        txt_path = os.path.join(txt_dir, os.path.splitext(jpg_file)[0] + '.txt')
        print(txt_path)
        with open(txt_path, 'w', encoding='utf-8') as file:
            file.write(text)
        print("Transformation terminée. Les fichiers TXT ont été créés.")
# Out:
# ../data/txt/ouvrages_feminins/20_part2/page_91.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_85.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_52.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_46.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_2.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_151.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_145.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_144.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_150.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_3.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_47.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_53.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_84.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_90.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_86.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_92.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_79.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_45.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_51.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_1.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_146.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_147.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_50.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_44.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_78.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_93.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_87.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_83.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_97.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_40.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_54.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_68.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_4.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_143.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_142.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_5.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_69.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_55.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_41.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_96.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_82.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_94.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_80.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_57.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_43.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_7.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_140.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_141.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_6.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_42.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_56.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_81.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_95.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_19.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_31.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_25.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_132.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_126.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_127.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_133.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_24.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_30.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_18.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_26.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_32.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_119.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_125.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_131.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_130.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_124.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_118.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_33.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_27.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_23.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_37.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_120.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_134.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_108.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_109.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_135.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_121.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_36.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_22.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_34.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_20.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_137.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_123.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_122.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_136.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_21.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_35.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_38.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_10.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_113.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_107.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_106.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_112.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_11.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_39.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_13.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_138.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_104.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_110.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_111.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_105.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_139.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_12.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_16.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_101.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_115.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_129.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_128.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_114.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_100.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_17.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_15.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_29.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_116.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_102.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_103.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_117.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_28.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_14.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_98.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_73.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_67.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_66.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_72.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_99.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_58.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_64.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_70.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_8.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_9.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_71.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_65.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_59.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_61.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_75.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_49.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_48.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_74.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_60.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_89.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_76.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_62.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_149.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_148.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_63.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_77.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part2/page_88.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_91.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_85.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_52.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_46.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_192.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_2.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_186.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_179.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_151.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_145.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_144.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_150.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_178.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_187.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_193.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_3.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_47.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_53.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_84.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_90.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_86.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_92.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_79.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_45.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_51.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_185.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_1.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_191.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_146.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_152.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_153.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_147.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_190.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_184.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_50.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_44.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_78.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_93.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_87.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_83.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_97.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_40.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_54.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_68.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_180.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_194.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_4.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_143.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_157.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_156.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_142.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_195.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_5.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_181.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_69.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_55.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_41.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_96.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_82.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_94.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_80.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_57.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_43.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_7.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_197.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_183.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_154.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_140.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_168.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_169.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_141.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_155.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_182.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_6.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_196.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_42.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_56.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_81.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_95.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_19.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_31.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_25.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_132.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_126.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_127.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_133.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_24.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_30.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_18.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_26.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_32.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_119.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_125.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_131.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_130.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_124.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_118.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_33.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_27.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_23.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_37.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_120.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_134.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_108.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_109.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_135.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_121.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_36.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_22.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_34.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_20.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_137.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_123.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_122.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_136.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_21.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_35.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_38.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_10.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_113.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_107.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_106.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_112.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_11.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_39.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_13.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_138.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_104.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_110.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_111.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_105.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_139.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_12.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_16.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_101.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_115.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_129.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_128.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_114.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_100.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_17.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_15.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_29.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_116.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_102.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_103.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_117.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_28.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_14.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_98.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_73.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_67.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_158.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_170.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_164.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_165.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_171.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_159.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_66.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_72.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_99.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_58.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_64.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_70.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_198.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_8.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_167.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_173.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_172.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_166.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_199.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_9.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_71.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_65.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_59.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_61.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_75.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_49.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_200.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_189.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_162.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_176.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_177.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_163.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_188.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_201.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_48.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_74.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_60.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_89.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_76.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_62.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_175.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_161.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_149.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_148.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_160.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_174.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_63.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_77.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part5/page_88.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_91.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_85.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_52.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_46.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_192.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_2.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_186.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_179.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_151.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_145.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_144.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_150.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_178.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_187.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_193.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_3.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_47.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_53.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_84.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_90.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_86.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_92.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_79.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_45.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_51.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_185.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_1.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_191.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_146.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_152.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_153.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_147.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_190.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_184.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_50.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_44.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_78.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_93.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_87.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_83.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_97.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_40.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_54.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_68.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_180.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_194.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_4.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_143.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_157.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_156.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_142.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_195.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_5.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_181.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_69.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_55.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_41.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_96.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_82.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_94.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_80.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_57.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_43.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_7.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_197.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_183.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_154.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_140.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_168.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_169.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_141.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_155.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_182.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_6.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_196.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_42.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_56.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_81.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_95.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_19.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_31.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_25.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_132.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_126.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_127.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_133.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_24.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_30.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_18.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_26.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part4/page_32.txt
# ...
# ../data/txt/ouvrages_feminins/20_part1/page_36.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_22.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_34.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_20.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_282.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_296.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_241.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_255.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_269.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_137.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_123.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_122.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_136.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_268.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_254.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_240.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_297.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_283.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_21.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_35.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_38.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_10.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_259.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_265.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_271.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_113.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_107.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_106.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_112.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_270.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_264.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_258.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_11.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_39.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_13.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_299.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_272.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_266.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_138.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_104.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_110.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_111.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_105.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_139.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_267.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_273.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_298.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_12.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_16.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_288.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_277.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_263.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_101.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_115.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_129.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_128.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_114.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_100.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_262.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_276.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_289.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_17.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_15.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_29.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_260.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_274.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_248.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_300.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_116.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_102.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_103.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_117.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_249.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_275.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_261.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_28.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_14.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_98.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_73.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_67.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_206.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_212.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_158.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_170.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_164.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_165.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_171.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_159.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_213.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_207.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_66.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_72.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_99.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_58.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_64.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_70.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_239.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_211.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_205.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_198.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_8.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_167.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_173.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_172.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_166.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_199.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_9.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_204.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_210.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_238.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_71.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_65.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_59.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_61.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_75.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_49.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_214.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_200.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_228.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_189.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_162.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_176.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_177.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_163.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_188.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_229.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_201.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_215.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_48.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_74.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_60.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_89.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_76.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_62.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_203.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_217.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_175.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_161.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_149.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_148.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_160.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_174.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_216.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_202.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_63.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_77.txt
# Transformation terminée. Les fichiers TXT ont été créés.
# ../data/txt/ouvrages_feminins/20_part1/page_88.txt
# Transformation terminée. Les fichiers TXT ont été créés.

# %%
import pytesseract
from PIL import Image, ImageOps
import os
import pandas as pd
import numpy as np
import cv2

dossier_jpg = '../sources/ouvrages_mixtes/02_part_1'

jpg_files = ["page_21.jpg"]

data = []
for jpg_file in jpg_files:
    image_path = os.path.join(subfolder, jpg_file)

    final_image = Image.fromarray(image)
    
    text = pytesseract.image_to_string(image, config='--oem 3 --psm 6')
    data.append({'filename': jpg_file, 'text': text})
    
    df = pd.DataFrame(data)
    
    dossier_nom = os.path.basename(subfolder)
    dossier_suffix = dossier_nom[-2:]
    
    txt_dir = f'../data/txt/ouvrages_mixtes/tests/{dossier_suffix}'
    if not os.path.exists(txt_dir):
        os.makedirs(txt_dir, exist_ok=True)
    txt_path = os.path.join(txt_dir, os.path.splitext(jpg_file)[0] + '.txt')
    with open(txt_path, 'w', encoding='utf-8') as file:
        file.write(text)

# %%
import os
import cv2
from PIL import Image
dossier_jpg = '../sources/ouvrages_mixtes/02_part_2'

jpg_files = ["page_13.jpg"]

data = []
for jpg_file in jpg_files:
    image_path = os.path.join(dossier_jpg, jpg_file)

    image = Image.open(image_path)
    image = image.convert('L', dither=None)
    image = image.point(lambda p: p > 175 and 255)
    #image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    #image = cv2.fastNlMeansDenoising(image, None, 8, 10, 21)
        
    #final_image = Image.fromarray(image)
    image.show()
